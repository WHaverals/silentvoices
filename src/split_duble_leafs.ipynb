# %%
import os
import glob

from wand.image import Image
from wand.display import display

i = 7
fol_start_num = 1


for filename in sorted(glob.glob("ms/*.tif")):
    
    with Image(filename=filename) as img:
        
        print(filename, img.size)
        #with img.clone() as copy1:
         #   copy1.crop(right=int(img.size[0]/2))
          #  num = str(i)
           # num = num.zfill(3)
            #copy1.save(filename=f'output_/{str(num)}_{fol_start_num}v.tif')
            #display(copy1)
            #i+=2
            #fol_start_num+=1
            
        with img.clone() as copy2:
            copy2.crop(left=int(img.size[0]/2))
            num = str(i)
            num = num.zfill(3)
            copy2.save(filename=f'output_/{num}_{fol_start_num}r.tif')
            #display(copy2)
            i+=2
            fol_start_num+=1
# Out:
# ms/é.60_005.tif (5706, 3898)
# ms/é.60_006.tif (5706, 3898)
# ms/é.60_007.tif (5706, 3898)
# ms/é.60_008.tif (5706, 3898)
# ms/é.60_009.tif (5706, 3898)
# ms/é.60_010.tif (5706, 3898)
# ms/é.60_011.tif (5706, 3898)
# ms/é.60_012.tif (5706, 3898)
# ms/é.60_013.tif (5706, 3898)
# ms/é.60_014.tif (5706, 3898)
# ms/é.60_015.tif (5706, 3898)
# ms/é.60_016.tif (5706, 3898)
# ms/é.60_017.tif (5706, 3898)
# ms/é.60_018.tif (5706, 3898)
# ms/é.60_019.tif (5706, 3898)
# ms/é.60_020.tif (5706, 3898)
# ms/é.60_021.tif (5706, 3898)
# ms/é.60_022.tif (5706, 3898)
# ms/é.60_023.tif (5706, 3898)
# ms/é.60_024.tif (5706, 3898)
# ms/é.60_025.tif (5706, 3898)
# ms/é.60_026.tif (5706, 3898)
# ms/é.60_027.tif (5706, 3898)
# ms/é.60_028.tif (5706, 3898)
# ms/é.60_029.tif (5706, 3898)
# ms/é.60_030.tif (5706, 3898)
# ms/é.60_031.tif (5706, 3898)
# ms/é.60_032.tif (5706, 3898)
# ms/é.60_033.tif (5706, 3898)
# ms/é.60_034.tif (5706, 3898)
# ms/é.60_035.tif (5706, 3898)
# ms/é.60_036.tif (5706, 3898)
# ...
