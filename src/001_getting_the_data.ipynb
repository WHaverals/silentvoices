# %% [markdown]
# ### 1. Download the data

# %%
import pandas as pd
import requests
import json
import sys

# Create a session
session = requests.Session()

# Replace 'username' and 'password' with your actual Transkribus username and password
login_payload = {"user": "##############", "pw": "##############"}

# Log in
response = session.post('https://transkribus.eu/TrpServer/rest/auth/login', data=login_payload)

# Check for successful login
if response.status_code == 200:
    print('Logged in successfully')
else:
    print('Failed to log in')
    sys.exit()

# After login, get a list of collections using the session
collections_response = session.get('https://transkribus.eu/TrpServer/rest/collections/list')

# Parse the JSON response into a Python dict
collections_dict = json.loads(collections_response.text)

# Find the collection ID for 'Silent Voices'
for collection in collections_dict:
    if collection['colName'] == 'Silent Voices':
        silent_voices_id = collection['colId']
        break
else:
    print("Collection 'Silent Voices' not found.")
    sys.exit()

# Get documents in the Silent Voices collection
documents_response = session.get(f'https://transkribus.eu/TrpServer/rest/collections/{silent_voices_id}/list')
documents_dict = json.loads(documents_response.text)

# Initialize an empty list to store the data
data = []

# Loop through the documents
for document in documents_dict:
    if document['title'] in ['Brussel, KBR, 1805-1808',
                             'Brussel, KBR, 2485',
                             'Brussel, KBR, 2849-51',
                             'Brussel, KBR, 2877-78',
                             'Brussel, KBR, 2879-80',
                             'Brussel, KBR, 2905-09',
                             'Brussel, KBR, 2979',
                             'Brussel, KBR, 3091',
                             'Brussel, KBR, 3093-95',
                             'Gent, UB, 1374', 
                             'Gent, UB, 941',
                             'Parijs, Bibliothèque Mazarine, 920',
                             "Parijs, Bibliothèque de l'Arsenal, 8224",
                             "Philadelphia, Lewis E 199",
                             "Sint-Petersburg, BAN, O 256",
                             "Wenen, ÖNB, 12.857",
                             "Wenen, ÖNB, 12.905",
                             "Wenen, ÖNB, 13.708",
                             "Wenen, ÖNB, 65"]:
        

        doc_id = document['docId']
        # Get full document data
        doc_response = session.get(f'https://transkribus.eu/TrpServer/rest/collections/{silent_voices_id}/{doc_id}/fulldoc')
        doc_dict = json.loads(doc_response.text)
        # Loop through the pages
        for page in doc_dict['pageList']['pages']:
            #print(page)
            page_id = page['pageId']
            page_nr = page['pageNr']
            img_file_name = page['imgFileName']
            ts_list = page['tsList']['transcripts']
            
            # Find the most recent transcript by comparing timestamp
            most_recent_ts = max(ts_list, key=lambda x: x['timestamp'])
            most_recent_url = most_recent_ts['url']  # Get the URL for the most recent transcript
            
            title = document['title']
            #print(title)
            transkribuspage = page_nr
            original_filename = img_file_name
            status = most_recent_ts['status']
            doc_id = most_recent_ts['docId']
            nr_of_transcribed_regions = most_recent_ts.get('nrOfTranscribedRegions', 0)
            nr_of_lines = most_recent_ts.get('nrOfLines', 0)
            nr_of_words = most_recent_ts.get('nrOfWords', 0)
            
            # Append the data to the list
            data.append([title, transkribuspage, original_filename, status, doc_id, nr_of_transcribed_regions, nr_of_lines, nr_of_words, most_recent_url])

# Create a DataFrame from the collected data
df = pd.DataFrame(data, columns=['codex_sig', 'transkribuspage', 'OriginalFilename', 'Status', 'DocId', 'NrOfTranscribedRegions', 'NrOfLines', 'NrOfWords', 'TranscriptURL'])

# Print the DataFrame
df
# Out:
# Logged in successfully
#                       codex_sig  transkribuspage  \
# 0            Brussel, KBR, 2485                1
# 1            Brussel, KBR, 2485                2
# 2            Brussel, KBR, 2485                3
# 3            Brussel, KBR, 2485                4
# 4            Brussel, KBR, 2485                5
# ...                         ...              ...
# 5863  Philadelphia, Lewis E 199               22
# 5864  Philadelphia, Lewis E 199               23
# 5865  Philadelphia, Lewis E 199               24
# 5866  Philadelphia, Lewis E 199               25
# 5867  Philadelphia, Lewis E 199               26
#
#                    OriginalFilename       Status    DocId  \
# 0                    0_front_r.jpeg           GT  1002641
# 1                    0_front_v.jpeg           GT  1002641
# 2                           1r.jpeg           GT  1002641
# 3                           1v.jpeg           GT  1002641
# 4                           2r.jpeg           GT  1002641
# ...                             ...          ...      ...
# 5863        022_Lewis_E199_back.tif  IN_PROGRESS  1320265
# 5864       023_Lewis_E199_spine.tif  IN_PROGRESS  1320265
# 5865    024_Lewis_E199_foreedge.tif  IN_PROGRESS  1320265
# 5866     025_Lewis_E199_topedge.tif  IN_PROGRESS  1320265
# 5867  026_Lewis_E199_bottomedge.tif  IN_PROGRESS  1320265
#
#       NrOfTranscribedRegions  NrOfLines  NrOfWords  \
# 0                          0          0          0
# 1                          0          0          0
# 2                          0          0          0
# 3                          1         21          0
# 4                          1         21          0
# ...                      ...        ...        ...
# 5863                       0          0          0
# 5864                       0          0          0
# 5865                       0          0          0
# 5866                       0          0          0
# 5867                       0          0          0
#
#                                           TranscriptURL
# 0     https://files.transkribus.eu/Get?id=XZSSLFCCHB...
# 1     https://files.transkribus.eu/Get?id=IJNNVGBLVW...
# 2     https://files.transkribus.eu/Get?id=QVJVECLALX...
# 3     https://files.transkribus.eu/Get?id=KIQXDUNKMG...
# 4     https://files.transkribus.eu/Get?id=VDAQYONNZE...
# ...                                                 ...
# 5863  https://files.transkribus.eu/Get?id=QCAURQABOA...
# 5864  https://files.transkribus.eu/Get?id=GCQOSAAOZG...
# 5865  https://files.transkribus.eu/Get?id=MNSPMYXBEW...
# 5866  https://files.transkribus.eu/Get?id=XLZYULOUCM...
# 5867  https://files.transkribus.eu/Get?id=XEECPTWSWL...
#
# [5868 rows x 9 columns]

# %%
df.head()
# Out:
#             codex_sig  transkribuspage OriginalFilename Status    DocId  \
# 0  Brussel, KBR, 2485                1   0_front_r.jpeg     GT  1002641
# 1  Brussel, KBR, 2485                2   0_front_v.jpeg     GT  1002641
# 2  Brussel, KBR, 2485                3          1r.jpeg     GT  1002641
# 3  Brussel, KBR, 2485                4          1v.jpeg     GT  1002641
# 4  Brussel, KBR, 2485                5          2r.jpeg     GT  1002641
#
#    NrOfTranscribedRegions  NrOfLines  NrOfWords  \
# 0                       0          0          0
# 1                       0          0          0
# 2                       0          0          0
# 3                       1         21          0
# 4                       1         21          0
#
#                                        TranscriptURL
# 0  https://files.transkribus.eu/Get?id=XZSSLFCCHB...
# 1  https://files.transkribus.eu/Get?id=IJNNVGBLVW...
# 2  https://files.transkribus.eu/Get?id=QVJVECLALX...
# 3  https://files.transkribus.eu/Get?id=KIQXDUNKMG...
# 4  https://files.transkribus.eu/Get?id=VDAQYONNZE...

# %%
import os
import requests

# Create the pagexml directory
base_dir = "../data/pagexmls"
os.makedirs(base_dir, exist_ok=True)

# Download files for each row in the DataFrame
for index, row in df.iterrows():
    title = row['codex_sig']
    url = row['TranscriptURL']
    folder_name = title #.replace(',', '').replace(' ', '_')
    folder_path = os.path.join(base_dir, folder_name)
    os.makedirs(folder_path, exist_ok=True)
    
    file_name = None

    # Send a HEAD request to retrieve the headers
    response = requests.head(url)
    if 'Content-Disposition' in response.headers:
        # Extract the filename from the Content-Disposition header
        header = response.headers['Content-Disposition']
        file_name = header.split('filename=')[1].strip('"')

    if not file_name:
        # If the filename couldn't be extracted from the header, use a default name
        file_name = 'file_' + str(index) + '.xml'

    save_path = os.path.join(folder_path, file_name)

    # Download the file
    response = requests.get(url)
    with open(save_path, 'wb') as file:
        file.write(response.content)
    print(f"Downloaded: {save_path}")
# Out:
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/0_front_r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/0_front_v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/1r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/1v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/2r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/2v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/3r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/3v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/4r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/4v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/5r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/5v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/6r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/6v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/7r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/7v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/8r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/8v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/9r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/9v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/10r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/10v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/11r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/11v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/12r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/12v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/13r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/13v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/14r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/14v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/15r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/15v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/16r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/16v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/17r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/17v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/18r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/18v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/19r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/19v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/20r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/20v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/21r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/21v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/22r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/22v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/23r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/23v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/24r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/24v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/25r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/25v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/26r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/26v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/27r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/27v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/28r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/28v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/29r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/29v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/30r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/30v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/31r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/31v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/32r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/32v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/33r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/33v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/34r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/34v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/35r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/35v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/36r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/36v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/37r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/37v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/38r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/38v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/39r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/39v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/40r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/40v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/41r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/41v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/42r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/42v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/43r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/43v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/44r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/44v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/45r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/45v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/46r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/46v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/47r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/47v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/48r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/48v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/49r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/49v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/50r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/50v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/51r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/51v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/52r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/52v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/53r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/53v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/54r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/54v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/55r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/55v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/56r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/56v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/57r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/57v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/58r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/58v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/59r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/59v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/60r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/60v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/61r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/61v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/62r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/62v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/63r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/63v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/64r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/64v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/65r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/65v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/66r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/66v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/67r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/67v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/68r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/68v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/69r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/69v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/70r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2485/back.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/2.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/3.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/4.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/5.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/6.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/7.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/8.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/9.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/10.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/11.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/12.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/13.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/14.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/15.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/16.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/17.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/18.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/19.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/20.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/21.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/22.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/23.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/24.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/25.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/26.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/27.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/28.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/29.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/30.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/31.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/32.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/33.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/34.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/35.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/36.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/37.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/38.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/39.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/40.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/41.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/42.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/43.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/44.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/45.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/46.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/47.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/48.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/49.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/50.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/51.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/52.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/53.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/54.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/55.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/56.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/57.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/58.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/59.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/60.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/61.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/62.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/63.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/64.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/65.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/66.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/67.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/68.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/69.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/70.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/71.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/72.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/73.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/74.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/75.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/76.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/77.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/78.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/79.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/80.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/81.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/82.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/83.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/84.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/85.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/86.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/87.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/88.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/89.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/90.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/91.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/92.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/93.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/94.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/95.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/96.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/97.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/98.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/99.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/100.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/101.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/102.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/103.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/104.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/105.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/106.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/107.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/108.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/109.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/110.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/111.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/112.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/113.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/114.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/115.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/116.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/117.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/118.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/119.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/120.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/121.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/122.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/123.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/124.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/125.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/126.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/127.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/128.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/129.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/130.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/131.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/132.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/133.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/134.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/135.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/136.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/137.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/138.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/139.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/140.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/141.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/142.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/143.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/144.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/145.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/146.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/147.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/148.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/149.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/150.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/151.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/152.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/153.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/154.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/155.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/156.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/157.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/158.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/159.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/160.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/161.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/162.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/163.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/164.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/165.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/166.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/167.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/168.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/169.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/170.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/171.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/172.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/173.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/174.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/175.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/176.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/177.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/178.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/179.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/180.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/181.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/182.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/183.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/184.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/185.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/186.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/187.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/188.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/189.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/190.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/191.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/192.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/193.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/194.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/195.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/196.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/197.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/198.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/199.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/200.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/201.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/202.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/203.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/204.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/205.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/206.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/207.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/208.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/209.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/210.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/211.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/212.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/213.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/214.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/215.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/216.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/217.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/218.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/219.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/220.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/221.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/222.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/223.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/224.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/225.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/226.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/227.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/228.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/229.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/230.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/231.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/232.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/233.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/234.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/235.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/236.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/237.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/238.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/239.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/240.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/241.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/242.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/243.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/244.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/245.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/246.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/247.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/248.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/249.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/250.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/251.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/252.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/253.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/254.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/255.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/256.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/257.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/258.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/259.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/260.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/261.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/262.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/263.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/264.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/265.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/266.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/267.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/268.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/269.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/270.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/271.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/272.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/273.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/274.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/275.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/276.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/277.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/278.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/279.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/280.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/281.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/282.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/283.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/284.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/285.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/286.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/287.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/288.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/289.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/290.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/291.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/292.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/293.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/294.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/295.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/296.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/297.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/298.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/299.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/300.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/301.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/302.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/303.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/304.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/305.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/306.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/307.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/308.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/309.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/310.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/311.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/312.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/313.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/314.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/315.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/316.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/317.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/318.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/319.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/320.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/321.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/322.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/323.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/324.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/325.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/326.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/327.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/328.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/329.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/330.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/331.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/332.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/333.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/334.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/335.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/336.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/337.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/338.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/339.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/340.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/341.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/342.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/343.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/344.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/345.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/346.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/347.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/348.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/349.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/350.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/351.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/352.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/353.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/354.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/355.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/356.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/357.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/358.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/359.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/360.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/361.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/362.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/363.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/364.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/365.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/366.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/367.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/368.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/369.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/370.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/371.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/372.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/373.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/374.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/375.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/376.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/377.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/378.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/379.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/380.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/381.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/382.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/383.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/384.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/385.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/386.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/387.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/388.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/389.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/390.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/391.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/392.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/393.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/394.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/395.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/396.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/397.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/398.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/399.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/400.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/401.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/402.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/403.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/404.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/405.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/406.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/407.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/408.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/409.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/410.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/411.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/412.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/413.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/414.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/415.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/416.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/417.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/418.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/419.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/420.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/421.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/422.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/423.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/424.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/425.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/426.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/427.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/428.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/429.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/430.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/431.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/432.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/433.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/434.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/435.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/436.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/437.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/438.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/439.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/440.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/441.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/442.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/443.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/444.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/445.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/446.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/447.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/448.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/449.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/450.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/451.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/452.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/453.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/454.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/455.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/456.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/457.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/458.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/459.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/460.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/461.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/462.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/463.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/464.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/465.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/466.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/467.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/468.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/469.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/470.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/471.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/472.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/473.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/474.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/475.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/476.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/477.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/478.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/479.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/480.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/481.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/482.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/483.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/484.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/485.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/486.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/487.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/488.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/489.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/490.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/491.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/492.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/493.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/494.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/495.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/496.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/497.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/498.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/499.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/500.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/501.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/502.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/503.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/504.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/505.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/506.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/507.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/508.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/509.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/510.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/511.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/512.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/513.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/514.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/515.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/516.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/517.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/518.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/519.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/520.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/521.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/522.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/523.xml
# Downloaded: ../data/pagexmls/Wenen, ÖNB, 13.708/524.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0001.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0002.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0003.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0004.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0005.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0006.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0007.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0008.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0009.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0010.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0011.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0012.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0013.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0014.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0015.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0016.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0017.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0018.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0019.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0020.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0021.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0022.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0023.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0024.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0025.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0026.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0027.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0028.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0029.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0030.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0031.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0032.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0033.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0034.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0035.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0036.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0037.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0038.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0039.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0040.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0041.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0042.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0043.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0044.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0045.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0046.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0047.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0048.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0049.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0050.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0051.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0052.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0053.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0054.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0055.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0056.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0057.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0058.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0059.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0060.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0061.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0062.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0063.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0064.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0065.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0066.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0067.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0068.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0069.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0070.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0071.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0072.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0073.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0074.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0075.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0076.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0077.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0078.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0079.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0080.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0081.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0082.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0083.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0084.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0085.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0086.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0087.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0088.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0089.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0090.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0091.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0092.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0093.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0094.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0095.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0096.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0097.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0098.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0099.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0100.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0101.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0102.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0103.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0104.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0105.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0106.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0107.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0108.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0109.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0110.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0111.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0112.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0113.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0114.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0115.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0116.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0117.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0118.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0119.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0120.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0121.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0122.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0123.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0124.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0125.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0126.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0127.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0128.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0129.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0130.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0131.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0132.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0133.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0134.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0135.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0136.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0137.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0138.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0139.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0140.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0141.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0142.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 3093-95/KBR_Ms3093-3095-0143.xml
# ...
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/147_KBR2979_70r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/148_KBR2979_70v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/149_KBR2979_71r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/150_KBR2979_71v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/151_KBR2979_72r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/152_KBR2979_72v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/153_KBR2979_73r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/154_KBR2979_73v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/155_KBR2979_74r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/156_KBR2979_74v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/157_KBR2979_75r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/158_KBR2979_75v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/159_KBR2979_76r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/160_KBR2979_76v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/161_KBR2979_77r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/162_KBR2979_77v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/163_KBR2979_78r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/164_KBR2979_78v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/165_KBR2979_79r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/166_KBR2979_79v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/167_KBR2979_80r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/168_KBR2979_80v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/169_KBR2979_81r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/170_KBR2979_81v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/171_KBR2979_82r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/172_KBR2979_82v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/173_KBR2979_83r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/174_KBR2979_83v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/175_KBR2979_84r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/176_KBR2979_84v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/177_KBR2979_85r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/178_KBR2979_85v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/179_KBR2979_86r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/180_KBR2979_86v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/181_KBR2979_87r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/182_KBR2979_87v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/183_KBR2979_88r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/184_KBR2979_88v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/185_KBR2979_89r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/186_KBR2979_89v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/187_KBR2979_90r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/188_KBR2979_90v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/189_KBR2979_91r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/190_KBR2979_91v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/191_KBR2979_92r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/192_KBR2979_92v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/193_KBR2979_93r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/194_KBR2979_93v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/195_KBR2979_94r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/196_KBR2979_94v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/197_KBR2979_95r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/198_KBR2979_95v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/199_KBR2979_96r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/200_KBR2979_96v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/201_KBR2979_97r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/202_KBR2979_97v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/203_KBR2979_98r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/204_KBR2979_98v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/205_KBR2979_99r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/206_KBR2979_99v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/207_KBR2979_100r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/208_KBR2979_100v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/209_KBR2979_101r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/210_KBR2979_101v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/211_KBR2979_102r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/212_KBR2979_102v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/213_KBR2979_103r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/214_KBR2979_103v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/215_KBR2979_104r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/216_KBR2979_104v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/217_KBR2979_105r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/218_KBR2979_105v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/219_KBR2979_106r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/220_KBR2979_106v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/221_KBR2979_107r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/222_KBR2979_107v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/223_KBR2979_108r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/224_KBR2979_108v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/225_KBR2979_109r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/226_KBR2979_109v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/227_KBR2979_110r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/228_KBR2979_110v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/229_KBR2979_111r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/230_KBR2979_111v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/231_KBR2979_112r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/232_KBR2979_112v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/233_KBR2979_113r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/234_KBR2979_113v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/235_KBR2979_114r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/236_KBR2979_114v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/237_KBR2979_115r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/238_KBR2979_115v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/239_KBR2979_116r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/240_KBR2979_116v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/241_KBR2979_117r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/242_KBR2979_117v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/243_KBR2979_118r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/244_KBR2979_118v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/245_KBR2979_119r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/246_KBR2979_119v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/247_KBR2979_120r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/248_KBR2979_120v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/249_KBR2979_121r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/250_KBR2979_121v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/251_KBR2979_122r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/252_KBR2979_122v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/253_KBR2979_123r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/254_KBR2979_123v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/255_KBR2979_124r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/256_KBR2979_124v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/257_KBR2979_125r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/258_KBR2979_125v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/259_KBR2979_126r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/260_KBR2979_126v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/261_KBR2979_127r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/262_KBR2979_127v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/263_KBR2979_128r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/264_KBR2979_128v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/265_KBR2979_129r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/266_KBR2979_129v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/267_KBR2979_130r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/268_KBR2979_130v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/269_KBR2979_131r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/270_KBR2979_131v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/271_KBR2979_132r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/272_KBR2979_132v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/273_KBR2979_133r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/274_KBR2979_133v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/275_KBR2979_134r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/276_KBR2979_134v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/277_KBR2979_135r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/278_KBR2979_135v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/279_KBR2979_136r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/280_KBR2979_136v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/281_KBR2979_137r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/282_KBR2979_137v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/283_KBR2979_138r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/284_KBR2979_138v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/285_KBR2979_139r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/286_KBR2979_139v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/287_KBR2979_140r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/288_KBR2979_140v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/289_KBR2979_141r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/290_KBR2979_141v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/291_KBR2979_142r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/292_KBR2979_142v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/293_KBR2979_143r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/294_KBR2979_143v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/295_KBR2979_144r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/296_KBR2979_144v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/297_KBR2979_145r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/298_KBR2979_145v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/299_KBR2979_146r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/300_KBR2979_146v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/301_KBR2979_147r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/302_KBR2979_147v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/303_KBR2979_148r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/304_KBR2979_148v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/305_KBR2979_149r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/306_KBR2979_149v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/307_KBR2979_150r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/308_KBR2979_150v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/309_KBR2979_151r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/310_KBR2979_151v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/311_KBR2979_152r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/312_KBR2979_152v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/313_KBR2979_153r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/314_KBR2979_153v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/315_KBR2979_154r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/316_KBR2979_154v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/317_KBR2979_155r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/318_KBR2979_155v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/319_KBR2979_156r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/320_KBR2979_156v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/321_KBR2979_157r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/322_KBR2979_157v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/323_KBR2979_158r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/324_KBR2979_158v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/325_KBR2979_159r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/326_KBR2979_159v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/327_KBR2979_160r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/328_KBR2979_160v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/329_KBR2979_161r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/330_KBR2979_161v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/331_KBR2979_162r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/332_KBR2979_162v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/333_KBR2979_163r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/334_KBR2979_163v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/335_KBR2979_164r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/336_KBR2979_164v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/337_KBR2979_165r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/338_KBR2979_165v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/339_KBR2979_166r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/340_KBR2979_166v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/341_KBR2979_167r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/342_KBR2979_167v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/343_KBR2979_168r.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/344_KBR2979_168v.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/345_KBR2979_flyleaf.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/346_KBR2979_flyleaf.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/347_KBR2979_flyleaf.xml
# Downloaded: ../data/pagexmls/Brussel, KBR, 2979/348_KBR2979_flyleaf.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/001_Lewis_E199_front.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/002_Lewis_E199_frontinside.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/003_Lewis_E199_flyleaf.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/004_Lewis_E199_flyleaf.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/005_Lewis_E199_1r.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/006_Lewis_E199_1v.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/007_Lewis_E199_2r.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/008_Lewis_E199_2v.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/009_Lewis_E199_3r.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/010_Lewis_E199_3v.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/011_Lewis_E199_4r.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/012_Lewis_E199_4v.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/013_Lewis_E199_5r.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/014_Lewis_E199_5v.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/015_Lewis_E199_6r.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/016_Lewis_E199_6v.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/017_Lewis_E199_7r.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/018_Lewis_E199_7v.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/019_Lewis_E199_flyleaf.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/020_Lewis_E199_flyleaf.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/021_Lewis_E199_flyleaf.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/022_Lewis_E199_back.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/023_Lewis_E199_spine.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/024_Lewis_E199_foreedge.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/025_Lewis_E199_topedge.xml
# Downloaded: ../data/pagexmls/Philadelphia, Lewis E 199/026_Lewis_E199_bottomedge.xml

# %% [markdown]
# ### 2. Extract metadata from PAGE XML files

# %% [markdown]
# The code block below extracts metadata from PAGE XML files and stores the data in a pandas DataFrame. The extracted metadata includes the **manuscript signature**, the **Transrkibus page number**, **image filename**, **image width** and **height**, **text region type**, **region coordinates**, **full text**, and **reading order**.
#
# Apart from this metadata which can be extracted from the PAGGE XML directly, we also calculate the **fraction** that a region takes up in an image. To this end, we first calculate the area of the region (using the Shoelace formula) and the area of the full image. Next, we divide the area of the text region by the area of the full image to get the fraction.
#
# The full DataFrame is then exported to an Excel file named `manuscript_data.xlsx`

# %%
import os
from tqdm import tqdm
import pandas as pd
from lxml import etree
import re

# Function to calculate area of a polygon given its coordinates
def polygon_area(coords):
    n = len(coords)
    area = 0.0
    for i in range(n):
        j = (i + 1) % n
        area += coords[i][0] * coords[j][1]
        area -= coords[j][0] * coords[i][1]
    return abs(area / 2.0)

# %%
def extract_metadata(page_files):
    ns = {'pc': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15'}
    metadata = pd.DataFrame(columns=['codex_sig', 'transkribuspage', 'image_filename', 'page_xml_filename', 'image_width', 'image_height', 'region_type', 'coordinates', 'fraction', 'text', 'reading_order', 'status'])
    for page_file in tqdm(page_files):
        page_filename = os.path.basename(page_file)
        with open(page_file, 'rb') as f:
            tree = etree.parse(f)

            # Change to match your directory structure
            manuscript = os.path.basename(os.path.dirname(page_file)).replace('_', ', ')

            image_filename = tree.xpath("//pc:Page/@imageFilename", namespaces=ns)
            image_filename = image_filename[0] if image_filename else None

            image_width = tree.xpath("//pc:Page/@imageWidth", namespaces=ns)
            image_width = int(image_width[0]) if image_width else None

            image_height = tree.xpath("//pc:Page/@imageHeight", namespaces=ns)
            image_height = int(image_height[0]) if image_height else None

            page_nr = tree.xpath("//pc:TranskribusMetadata/@pageNr", namespaces=ns)
            page_nr = int(page_nr[0]) if page_nr else None

            status = tree.xpath("//pc:TranskribusMetadata/@status", namespaces=ns)
            status = status[0] if status else None

            for text_region in tree.xpath('//pc:TextRegion', namespaces=ns):
                region_type = text_region.get('type')
                custom = text_region.get('custom')
                reading_order = custom.split("index:")[1].split(";")[0].strip() if custom else None

                for coords in text_region.xpath('./pc:Coords[1]/@points', namespaces=ns):
                    text_region_coords = coords
                    region_coords = text_region_coords.split()
                    #print(region_coords)
                    region_coords = [(int(coord.split(',')[0]), int(coord.split(',')[1])) for coord in region_coords]
                    polygon_area_size = polygon_area(region_coords)
                    image_area = image_width * image_height if image_width and image_height else None
                    fraction = polygon_area_size / image_area if image_area else None
                    formatted_fraction = "{:.2f}".format(fraction) if fraction else None

                full_text = []
                for text_line in text_region.xpath('.//pc:TextLine', namespaces=ns):
                    unicode_list = text_line.xpath('./pc:TextEquiv[last()]/pc:Unicode', namespaces=ns)
                    final_unicode = unicode_list[0].text if len(unicode_list) > 0 else ' '
                    full_text.append(final_unicode)

                final_text = '\n'.join(filter(None, full_text))
                
                row = {
                    'codex_sig': [manuscript],
                    'transkribuspage': [page_nr],
                    'image_filename': [image_filename],
                    'page_xml_filename': [page_filename],
                    'image_width': [image_width],
                    'image_height': [image_height],
                    'region_type': [region_type],
                    'coordinates': [text_region_coords],
                    'fraction': [formatted_fraction],
                    'text': [final_text],
                    'reading_order' : [reading_order],
                    'status': [status]}

                metadata = pd.concat([metadata, pd.DataFrame(row)], ignore_index=True)
    return metadata

page_files = []
for root, dirs, files in os.walk('../data/pagexmls'):
    for file in files:
        if file.endswith('.xml'):
            page_files.append(os.path.join(root, file))

df = extract_metadata(page_files)

# Sorting the DataFrame by 'codex_sig' and 'transkribuspage'
df = df.sort_values(by=['codex_sig', 'transkribuspage'], ascending=[True, True])
# Resetting the index to reflect the new order
df = df.reset_index(drop=True)
# Save the sorted DataFrame to an Excel file
df.to_excel('../data/manuscript_data_new.xlsx', index=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 5874/5874 [00:31<00:00, 185.55it/s]

# %%
df
# Out:
#                      codex_sig transkribuspage            image_filename  \
# 0      Brussel, KBR, 1805-1808               7  0007_KBR_1805-08_1r.tiff
# 1      Brussel, KBR, 1805-1808               7  0007_KBR_1805-08_1r.tiff
# 2      Brussel, KBR, 1805-1808               8             47180129.tiff
# 3      Brussel, KBR, 1805-1808               8             47180129.tiff
# 4      Brussel, KBR, 1805-1808               9  0009_KBR_1805-08_2r.tiff
# ...                        ...             ...                       ...
# 13758          Wenen, ÖNB, 65             193              50510902.jpg
# 13759          Wenen, ÖNB, 65             193              50510902.jpg
# 13760          Wenen, ÖNB, 65             194              50510904.jpg
# 13761          Wenen, ÖNB, 65             194              50510904.jpg
# 13762          Wenen, ÖNB, 65             194              50510904.jpg
#
#              page_xml_filename image_width image_height region_type  \
# 0      0007_KBR_1805-08_1r.xml        5186         7123      header
# 1      0007_KBR_1805-08_1r.xml        5186         7123   paragraph
# 2      0008_KBR_1805-08_1v.xml        5186         7123   paragraph
# 3      0008_KBR_1805-08_1v.xml        5186         7123  marginalia
# 4      0009_KBR_1805-08_2r.xml        5186         7123   paragraph
# ...                        ...         ...          ...         ...
# 13758             00000193.xml        1944         2598   paragraph
# 13759             00000193.xml        1944         2598  marginalia
# 13760             00000194.xml        1932         2625   paragraph
# 13761             00000194.xml        1932         2625   paragraph
# 13762             00000194.xml        1932         2625  marginalia
#
#                                              coordinates fraction  \
# 0                    1405,478 3598,478 3598,721 1405,721     0.01
# 1                  1359,751 3792,751 3792,2645 1359,2645     0.12
# 2                  1736,658 3985,658 3985,1643 1736,1643     0.06
# 3                2414,1705 4016,1705 4016,1851 2414,1851     0.01
# 4      859,5840 847,5678 835,5462 781,4838 751,4480 7...     0.23
# ...                                                  ...      ...
# 13758                952,250 1747,250 1747,2108 952,2108     0.29
# 13759            1757,1097 1757,1185 1825,1187 1825,1099     0.00
# 13760                281,276 281,2114 1029,2114 1029,276     0.27
# 13761                1105,276 1106,578 1866,578 1865,276     0.05
# 13762                1101,585 1797,585 1797,658 1101,658     0.01
#
#                                                     text reading_order  \
# 0              Een voorredene op sinte gregoriꝰ dyalogus             0
# 1      DE zeere wise e saleghe gregoris paeus\nvan d...             1
# 2      wiste dat si hare te xpūs gheloeue ghege-\nuen...             0
# 3                      ⸫ Nēmeer en vant ics jnt latijn .             1
# 4      Hier beghint een voʼredene\nop .Sʼ. gᵉgorius d...             0
# ...                                                  ...           ...
# 13758  so verre kinne vandē volcomenen\nloue der heil...             2
# 13759                                                noᵃ             3
# 13760  glorificerē selen inder eewicheit .\nDe die pe...             0
# 13761  Dit boec es in dietsche vten lati-\nne ghetogh...             1
# 13762                       Dies biedic s Oddʼ si anet v             2
#
#             status
# 0             None
# 1             None
# 2      IN_PROGRESS
# 3      IN_PROGRESS
# 4      IN_PROGRESS
# ...            ...
# 13758  IN_PROGRESS
# 13759  IN_PROGRESS
# 13760         DONE
# 13761         DONE
# 13762         DONE
#
# [13763 rows x 12 columns]

# %% [markdown]
# ### 3. Merge with additional information stored in another spreadsheet

# %%
## OPTION 1: access sheet through Google Drive API
#!pip install gspread

import gspread
sa = gspread.service_account(filename="../auth/silentvoices-fb9908394ef8.json")
sheet = sa.open_by_url("https://docs.google.com/spreadsheets/d/1EJQtcZ63ZA6Po3HAhBchMkrcwTQMhFp1W1XjkW1wwuc")

# Get list of all worksheets
all_worksheets = sheet.worksheets()

# Initialize an empty dictionary to store the dataframes
dfs = {}

# Loop through each worksheet
for ws in all_worksheets:
    print(ws)
    # Get all values of the worksheet
    values = ws.get_all_values()
    # Only keep the first 15 columns (A to O in Excel)
    values = [row[:15] for row in values]
    # Convert to a dataframe, assuming first row is the header
    df_temp = pd.DataFrame(values[1:], columns=values[0])
    
    # Store the dataframe in the dictionary
    dfs[ws.title] = df_temp

# Remove the 'OVERVIEW' sheet
if 'OVERVIEW' in dfs:
    del dfs['OVERVIEW']

# Concatenate the dataframes
add_df = pd.concat(dfs.values(), ignore_index=True)
# Out:
# <Worksheet 'OVERVIEW' id:1053394346>
# <Worksheet 'KBR 394-98' id:2016912023>
# <Worksheet 'KBR 1805-08' id:762308753>
# <Worksheet 'KBR 2485' id:0>
# <Worksheet 'KBR 2849-51' id:956390397>
# <Worksheet 'KBR 2877-78' id:387871519>
# <Worksheet 'KBR 2879-80' id:352703624>
# <Worksheet 'KBR 2905-09' id:460677957>
# <Worksheet 'KBR 2979' id:1622097260>
# <Worksheet 'KBR 3091' id:1367553580>
# <Worksheet 'KBR 3093-95' id:2032175414>
# <Worksheet 'Ghent UB 941' id:1567686002>
# <Worksheet 'Ghent UB 1374' id:773429885>
# <Worksheet 'BA 8224' id:841632581>
# <Worksheet 'MA 920' id:1158373373>
# <Worksheet 'BAN O256' id:1901642224>
# <Worksheet 'ÖNB 13708' id:19886449>
# <Worksheet 'ÖNB 65' id:1868536383>
# <Worksheet 'ÖNB 12905' id:2075030953>
# <Worksheet 'ÖNB 12857' id:571355786>
# <Worksheet 'Lewis E 199' id:1609201371>

# %%
import unicodedata

df['page_xml_filename'] = df['page_xml_filename'].astype(str)
add_df['page_xml_filename'] = add_df['page_xml_filename'].astype(str)

df['codex_sig'] = df['codex_sig'].apply(lambda x: unicodedata.normalize('NFC', x))
add_df['codex_sig'] = add_df['codex_sig'].apply(lambda x: unicodedata.normalize('NFC', x))

print(df['codex_sig'].unique())
#print(df['transkribuspage'].unique())
print(df['codex_sig'].dtypes)
#print(df['transkribuspage'].dtypes)
print(add_df['codex_sig'].unique())
#print(add_df['transkribuspage'].unique())
print(add_df['codex_sig'].dtypes)
#print(add_df['transkribuspage'].dtypes)
# Out:
# ['Brussel, KBR, 1805-1808' 'Brussel, KBR, 2485' 'Brussel, KBR, 2849-51'
#  'Brussel, KBR, 2877-78' 'Brussel, KBR, 2879-80' 'Brussel, KBR, 2905-09'
#  'Brussel, KBR, 2979' 'Brussel, KBR, 3091' 'Brussel, KBR, 3093-95'
#  'Gent, UB, 1374' 'Gent, UB, 941' 'Parijs, Bibliothèque Mazarine, 920'
#  "Parijs, Bibliothèque de l'Arsenal, 8224" 'Philadelphia, Lewis E 199'
#  'Sint-Petersburg, BAN, O 256' 'TRAINING, VALIDATION, SET, 2849-51, v1'
#  'Wenen, ÖNB, 12.857' 'Wenen, ÖNB, 12.905' 'Wenen, ÖNB, 13.708'
#  'Wenen, ÖNB, 65']
# object
# ['Brussel, KBR, 394-98' 'Brussel, KBR, 1805-1808' 'Brussel, KBR, 2485'
#  'Brussel, KBR, 2849-51' 'Brussel, KBR, 2877-78' 'Brussel, KBR, 2879-80'
#  'Brussel, KBR, 2905-09' 'Brussel, KBR, 2979' 'Brussel, KBR, 3091'
#  'Brussel, KBR, 3093-95' 'Gent, UB, 941' 'Gent, UB, 1374'
#  "Parijs, Bibliothèque de l'Arsenal, 8224"
#  'Parijs, Bibliothèque Mazarine, 920' 'Sint-Petersburg, BAN, O 256' ''
#  'Wenen, ÖNB, 13.708' 'Wenen, ÖNB, 65' 'Wenen, ÖNB, 12.905'
#  'Wenen, ÖNB, 12.857' 'Philadelphia, Lewis E 199']
# object

# %%
# Merge the dataframes
df_merged = pd.merge(df, add_df, on=['codex_sig', 'page_xml_filename'], how='left')

# Save merged dataframe
df_merged.to_excel('../data/manuscript_data_metadata.xlsx')

# %%
df_merged
# Out:
#                      codex_sig transkribuspage_x            image_filename  \
# 0      Brussel, KBR, 1805-1808                 7  0007_KBR_1805-08_1r.tiff
# 1      Brussel, KBR, 1805-1808                 7  0007_KBR_1805-08_1r.tiff
# 2      Brussel, KBR, 1805-1808                 8             47180129.tiff
# 3      Brussel, KBR, 1805-1808                 8             47180129.tiff
# 4      Brussel, KBR, 1805-1808                 9  0009_KBR_1805-08_2r.tiff
# ...                        ...               ...                       ...
# 13758           Wenen, ÖNB, 65               193              50510902.jpg
# 13759           Wenen, ÖNB, 65               193              50510902.jpg
# 13760           Wenen, ÖNB, 65               194              50510904.jpg
# 13761           Wenen, ÖNB, 65               194              50510904.jpg
# 13762           Wenen, ÖNB, 65               194              50510904.jpg
#
#              page_xml_filename image_width image_height region_type  \
# 0      0007_KBR_1805-08_1r.xml        5186         7123      header
# 1      0007_KBR_1805-08_1r.xml        5186         7123   paragraph
# 2      0008_KBR_1805-08_1v.xml        5186         7123   paragraph
# 3      0008_KBR_1805-08_1v.xml        5186         7123  marginalia
# 4      0009_KBR_1805-08_2r.xml        5186         7123   paragraph
# ...                        ...         ...          ...         ...
# 13758             00000193.xml        1944         2598   paragraph
# 13759             00000193.xml        1944         2598  marginalia
# 13760             00000194.xml        1932         2625   paragraph
# 13761             00000194.xml        1932         2625   paragraph
# 13762             00000194.xml        1932         2625  marginalia
#
#                                              coordinates fraction  \
# 0                    1405,478 3598,478 3598,721 1405,721     0.01
# 1                  1359,751 3792,751 3792,2645 1359,2645     0.12
# 2                  1736,658 3985,658 3985,1643 1736,1643     0.06
# 3                2414,1705 4016,1705 4016,1851 2414,1851     0.01
# 4      859,5840 847,5678 835,5462 781,4838 751,4480 7...     0.23
# ...                                                  ...      ...
# 13758                952,250 1747,250 1747,2108 952,2108     0.29
# 13759            1757,1097 1757,1185 1825,1187 1825,1099     0.00
# 13760                281,276 281,2114 1029,2114 1029,276     0.27
# 13761                1105,276 1106,578 1866,578 1865,276     0.05
# 13762                1101,585 1797,585 1797,658 1101,658     0.01
#
#                                                     text  ...     layout  \
# 0              Een voorredene op sinte gregoriꝰ dyalogus  ...  corrected
# 1      DE zeere wise e saleghe gregoris paeus\nvan d...  ...  corrected
# 2      wiste dat si hare te xpūs gheloeue ghege-\nuen...  ...  corrected
# 3                      ⸫ Nēmeer en vant ics jnt latijn .  ...  corrected
# 4      Hier beghint een voʼredene\nop .Sʼ. gᵉgorius d...  ...  corrected
# ...                                                  ...  ...        ...
# 13758  so verre kinne vandē volcomenen\nloue der heil...  ...  corrected
# 13759                                                noᵃ  ...  corrected
# 13760  glorificerē selen inder eewicheit .\nDe die pe...  ...  corrected
# 13761  Dit boec es in dietsche vten lati-\nne ghetogh...  ...  corrected
# 13762                       Dies biedic s Oddʼ si anet v  ...  corrected
#
#                content     language scribe production unit  \
# 0              proloog  middledutch      a               I
# 1              proloog  middledutch      a               I
# 2              proloog  middledutch      a               I
# 3              proloog  middledutch      a               I
# 4      dialogenGreg1_3  middledutch      α               I
# ...                ...          ...    ...             ...
# 13758        horlogium  middledutch      γ              IV
# 13759        horlogium  middledutch      γ              IV
# 13760        horlogium  middledutch      γ              IV
# 13761        horlogium  middledutch      γ              IV
# 13762        horlogium  middledutch      γ              IV
#
#       local Herne product       date       translator transcription  \
# 0                     yes       1400  bibletranslator            GT
# 1                     yes       1400  bibletranslator            GT
# 2                     yes       1400  bibletranslator            GT
# 3                     yes       1400  bibletranslator            GT
# 4                     yes       1395  bibletranslator            GT
# ...                   ...        ...              ...           ...
# 13758                 yes  1375-1400                            HTR
# 13759                 yes  1375-1400                            HTR
# 13760                 yes  1375-1400                            HTR
# 13761                 yes  1375-1400                            HTR
# 13762                 yes  1375-1400                            HTR
#
#                HTR-model used
# 0
# 1
# 2
# 3
# 4
# ...                       ...
# 13758  BigMiddleDutchModel_v2
# 13759  BigMiddleDutchModel_v2
# 13760  BigMiddleDutchModel_v2
# 13761  BigMiddleDutchModel_v2
# 13762  BigMiddleDutchModel_v2
#
# [13763 rows x 25 columns]

# %%
# OPTION 2: donwnload the codex_info file from GDrive and load the data from that file

# we're going to merge the spreadsheet with other information, relating to the corpus (such as: scribe, production unit, etc.)
fn = '../data/codex_info.xlsx'
sheets = pd.read_excel(fn, sheet_name=None)
del sheets['OVERVIEW'] # delete the overview-sheet

# %%
sheets.keys() # names of the sheets (i.e. manuscript sigla)
# Out:
# dict_keys(['KBR 394-98', 'KBR 1805-08', 'KBR 2485', 'KBR 2849-51', 'KBR 2877-78', 'KBR 2879-80', 'KBR 2905-09', 'KBR 2979', 'KBR 3091', 'KBR 3093-95', 'Ghent UB 941', 'Ghent UB 1374', 'BA 8224', 'MA 920', 'BAN O256', 'ÖNB 13708', 'ÖNB 65', 'ÖNB 12905', 'ÖNB 12857', 'Lewis E 199'])

# %%
add_df = pd.concat(sheets.values())
add_df.reset_index(inplace=True, drop=True)
columns_to_drop = ['Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18']
for column in columns_to_drop:
    if column in add_df.columns:
        add_df.drop(column, axis=1, inplace=True)

# %%
add_df.head()
# Out:
#               codex_sig  transkribuspage                    filename folium  \
# 0  Brussel, KBR, 394-98                1  0001_KBR_394-98_cover.tiff  cover
# 1  Brussel, KBR, 394-98                2  0002_KBR_394-98_blank.tiff  blank
# 2  Brussel, KBR, 394-98                3  0003_KBR_394-98_blank.tiff  blank
# 3  Brussel, KBR, 394-98                4  0004_KBR_394-98_blank.tiff  blank
# 4  Brussel, KBR, 394-98                5     0005_KBR_394-98_1r.tiff     1r
#
#       layout   content language scribe production unit local Herne product  \
# 0  corrected      none     none   none            none                  no
# 1  corrected      none     none   none            none                  no
# 2  corrected      none     none   none            none                none
# 3  corrected      none     none   none            none                none
# 4  corrected  calendar     none      A               I                 yes
#
#         date translator transcription HTR-model used  CER?
# 0  1450-1500        NaN          none            NaN   NaN
# 1  1450-1500        NaN          none            NaN   NaN
# 2       none        NaN          none            NaN   NaN
# 3       none        NaN          none            NaN   NaN
# 4  1373-1383        NaN          none            NaN   NaN

# %%
# we merge the two dataframes
df_merged = pd.merge(df, add_df, on=['codex_sig', 'transkribuspage'], how='left')

# save merged dataframe
df_merged.to_excel('../data/manuscript_data_metadata.xlsx')

# %%
df_merged
# Out:
#                      codex_sig transkribuspage            image_filename  \
# 0      Brussel, KBR, 1805-1808               7  0007_KBR_1805-08_1r.tiff
# 1      Brussel, KBR, 1805-1808               7  0007_KBR_1805-08_1r.tiff
# 2      Brussel, KBR, 1805-1808               8             47180129.tiff
# 3      Brussel, KBR, 1805-1808               8             47180129.tiff
# 4      Brussel, KBR, 1805-1808               9  0009_KBR_1805-08_2r.tiff
# ...                        ...             ...                       ...
# 13758          Wenen, ÖNB, 65             193              50510902.jpg
# 13759          Wenen, ÖNB, 65             193              50510902.jpg
# 13760          Wenen, ÖNB, 65             194              50510904.jpg
# 13761          Wenen, ÖNB, 65             194              50510904.jpg
# 13762          Wenen, ÖNB, 65             194              50510904.jpg
#
#              page_xml_filename image_width image_height region_type  \
# 0      0007_KBR_1805-08_1r.xml        5186         7123      header
# 1      0007_KBR_1805-08_1r.xml        5186         7123   paragraph
# 2      0008_KBR_1805-08_1v.xml        5186         7123   paragraph
# 3      0008_KBR_1805-08_1v.xml        5186         7123  marginalia
# 4      0009_KBR_1805-08_2r.xml        5186         7123   paragraph
# ...                        ...         ...          ...         ...
# 13758             00000193.xml        1944         2598   paragraph
# 13759             00000193.xml        1944         2598  marginalia
# 13760             00000194.xml        1932         2625   paragraph
# 13761             00000194.xml        1932         2625   paragraph
# 13762             00000194.xml        1932         2625  marginalia
#
#                                              coordinates fraction  \
# 0                    1405,478 3598,478 3598,721 1405,721     0.01
# 1                  1359,751 3792,751 3792,2645 1359,2645     0.12
# 2                  1736,658 3985,658 3985,1643 1736,1643     0.06
# 3                2414,1705 4016,1705 4016,1851 2414,1851     0.01
# 4      859,5840 847,5678 835,5462 781,4838 751,4480 7...     0.23
# ...                                                  ...      ...
# 13758                952,250 1747,250 1747,2108 952,2108     0.29
# 13759            1757,1097 1757,1185 1825,1187 1825,1099     0.00
# 13760                281,276 281,2114 1029,2114 1029,276     0.27
# 13761                1105,276 1106,578 1866,578 1865,276     0.05
# 13762                1101,585 1797,585 1797,658 1101,658     0.01
#
#                                                     text  ...  \
# 0              Een voorredene op sinte gregoriꝰ dyalogus  ...
# 1      DE zeere wise e saleghe gregoris paeus\nvan d...  ...
# 2      wiste dat si hare te xpūs gheloeue ghege-\nuen...  ...
# 3                      ⸫ Nēmeer en vant ics jnt latijn .  ...
# 4      Hier beghint een voʼredene\nop .Sʼ. gᵉgorius d...  ...
# ...                                                  ...  ...
# 13758  so verre kinne vandē volcomenen\nloue der heil...  ...
# 13759                                                noᵃ  ...
# 13760  glorificerē selen inder eewicheit .\nDe die pe...  ...
# 13761  Dit boec es in dietsche vten lati-\nne ghetogh...  ...
# 13762                       Dies biedic s Oddʼ si anet v  ...
#
#                content     language scribe production unit  \
# 0              proloog  middledutch      a               I
# 1              proloog  middledutch      a               I
# 2              proloog  middledutch      a               I
# 3              proloog  middledutch      a               I
# 4      dialogenGreg1_3  middledutch      α               I
# ...                ...          ...    ...             ...
# 13758              NaN          NaN    NaN             NaN
# 13759              NaN          NaN    NaN             NaN
# 13760              NaN          NaN    NaN             NaN
# 13761              NaN          NaN    NaN             NaN
# 13762              NaN          NaN    NaN             NaN
#
#       local Herne product  date       translator transcription HTR-model used  \
# 0                     yes  1400  bibletranslator            GT            NaN
# 1                     yes  1400  bibletranslator            GT            NaN
# 2                     yes  1400  bibletranslator            GT            NaN
# 3                     yes  1400  bibletranslator            GT            NaN
# 4                     yes  1395  bibletranslator            GT            NaN
# ...                   ...   ...              ...           ...            ...
# 13758                 NaN   NaN              NaN           NaN            NaN
# 13759                 NaN   NaN              NaN           NaN            NaN
# 13760                 NaN   NaN              NaN           NaN            NaN
# 13761                 NaN   NaN              NaN           NaN            NaN
# 13762                 NaN   NaN              NaN           NaN            NaN
#
#       CER?
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 13758  NaN
# 13759  NaN
# 13760  NaN
# 13761  NaN
# 13762  NaN
#
# [13763 rows x 25 columns]

# %% [markdown]
# ### 3. Add HTR-data to the dataframe

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Load the excel file
df = pd.read_excel('../data/manuscript_data_rich.xlsx')

# Filter dataframe by language
df = df[df['language'] == 'middledutch']

# Fill NaN values in the 'text' column with an empty string
df['text'] = df['text'].fillna('')

# Initialize CountVectorizer for text tokenization
vectorizer = CountVectorizer(tokenizer=lambda text: text.split())

results = []
# Group by codex_sig and iterate
for codex, group in df.groupby('codex_sig'):
    result = {}
    result['Witness'] = codex

    # Split production units on '-' and count unique units
    unique_production_units = set()
    for unit in group['production unit'].dropna():
        unique_production_units.update(unit.split('-'))
    result['Production units containing Middle Dutch text'] = len(unique_production_units)

    # Count unique folium values
    result['Folia (recto and verso)'] = group['folium'].nunique()

    # Tokenize text column and count total and unique tokens
    tokens = vectorizer.fit_transform(group['text']).toarray()
    total_tokens = tokens.sum()
    unique_tokens = len(vectorizer.get_feature_names_out())

    result['Number of tokens'] = total_tokens
    result['Type-token ratio'] = total_tokens / unique_tokens if unique_tokens != 0 else 0
    
    # Count unique characters
    unique_chars = set(''.join(group['text']))
    result['Number of unique characters'] = len(unique_chars)

    # Split scribe units on '-' and count unique units, disregard 'none', 'unknown' and empty cells
    unique_scribes = set()
    for scribe in group['scribe'].dropna():
        if scribe.lower() not in ['none', 'unknown']:
            unique_scribes.update(scribe.split('-'))
    result['Number of unique scribes'] = len(unique_scribes)

    results.append(result)

# Convert results to dataframe
result_df = pd.DataFrame(results)

# %%
result_df
# Out:
#                                     Witness  \
# 0                   Brussel, KBR, 1805-1808
# 1                        Brussel, KBR, 2485
# 2                     Brussel, KBR, 2849-51
# 3                     Brussel, KBR, 2877-78
# 4                     Brussel, KBR, 2879-80
# 5                     Brussel, KBR, 2905-09
# 6                        Brussel, KBR, 2979
# 7                        Brussel, KBR, 3091
# 8                     Brussel, KBR, 3093-95
# 9                            Gent, UB, 1374
# 10                            Gent, UB, 941
# 11       Parijs, Bibliothèque Mazarine, 920
# 12  Parijs, Bibliothèque de l'Arsenal, 8224
# 13              Sint-Petersburg, BAN, O 256
# 14                       Wenen, ÖNB, 12.857
# 15                       Wenen, ÖNB, 12.905
# 16                       Wenen, ÖNB, 13.708
# 17                           Wenen, ÖNB, 65
#
#     Production units containing Middle Dutch text  Folia (recto and verso)  \
# 0                                               3                      132
# 1                                               2                      135
# 2                                               7                      693
# 3                                               2                      330
# 4                                               3                      202
# 5                                              10                      384
# 6                                               2                       49
# 7                                               1                      452
# 8                                               2                      374
# 9                                               5                      264
# 10                                              2                       91
# 11                                              8                      285
# 12                                              2                       22
# 13                                              5                      172
# 14                                              4                      479
# 15                                              1                      400
# 16                                             11                      490
# 17                                              4                      186
#
#     Number of tokens  Type-token ratio  Number of unique characters  \
# 0              95503          6.727932                          107
# 1              27442          5.985169                           87
# 2             154399          8.096010                          122
# 3              90181          7.614709                           84
# 4              82113          7.431713                           93
# 5              46954          5.734489                           94
# 6                216          1.611940                           45
# 7              75179          7.692520                           96
# 8              40444          5.194452                          101
# 9              77717          7.281645                          116
# 10             29563          5.508291                           75
# 11             54893          5.339267                           97
# 12              1020          1.658537                           61
# 13             43375          4.956576                           95
# 14             84063          7.732064                          104
# 15             73196          6.130318                           96
# 16            281228          8.300708                          118
# 17             74160          6.340087                           92
#
#     Number of unique scribes
# 0                          4
# 1                          1
# 2                          1
# 3                          1
# 4                          3
# 5                          2
# 6                          3
# 7                          2
# 8                          2
# 9                          1
# 10                         2
# 11                         7
# 12                         3
# 13                         3
# 14                         4
# 15                         2
# 16                         1
# 17                         2

# %%
# Save the result_df DataFrame to an Excel file
result_df.to_excel("manuscript_analysis.xlsx", index=False)
